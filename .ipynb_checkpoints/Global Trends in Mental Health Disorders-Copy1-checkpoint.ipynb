# %% [markdown]
# # Global Trends in Mental Health Disorders
# The data used in this analysis was obtained here: https://data.world/vizzup/mental-health-depression-disorder-data

# %%
import pandas as pd

excel_file = pd.ExcelFile('Mental health Depression disorder Data.xlsx')
# Get the list of sheet names
sheet_names = excel_file.sheet_names
sheet_names
# Out:
# ['prevalence-by-mental-and-substa',
#  'depression-by-level-of-educatio',
#  'prevalence-of-depression-by-age',
#  'prevalence-of-depression-males-',
#  'suicide-rates-vs-prevalence-of-',
#  'number-with-depression-by-count']

# %%
# Create a dictionary to store DataFrames for each sheet
dfs = {}

# Iterate over each sheet and store its DataFrame in the dictionary
for sheet_name in sheet_names:
    dfs[sheet_name] = excel_file.parse(sheet_name)

# %%
df1 = dfs['prevalence-by-mental-and-substa']
df2 = dfs['depression-by-level-of-educatio']
df3 = dfs['prevalence-of-depression-by-age']
df4 = dfs['prevalence-of-depression-males-']
df5 = dfs['suicide-rates-vs-prevalence-of-']
df6 = dfs['number-with-depression-by-count']

# %% [markdown]
# ## Prevalence Rates of Mental Health Conditions Across Different Years: A Country-Level Analysis
# The dataset comprises records documenting the prevalence rates (%) of various mental health conditions (Schizophrenia, Bipolar disorder, Eating disorders, Anxiety disorders, Drug use disorders, Depression, Alcohol use disorders) across different years, identified by specific countries.

# %%
df1
# Out:
#            Entity Code    Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 0     Afghanistan  AFG  1990.0           0.160560              0.697779
# 1     Afghanistan  AFG  1991.0           0.160312              0.697961
# 2     Afghanistan  AFG  1992.0           0.160135              0.698107
# 3     Afghanistan  AFG  1993.0           0.160037              0.698257
# 4     Afghanistan  AFG  1994.0           0.160022              0.698469
# ...           ...  ...     ...                ...                   ...
# 6463     Zimbabwe  ZWE  2013.0           0.155670              0.607993
# 6464     Zimbabwe  ZWE  2014.0           0.155993              0.608610
# 6465     Zimbabwe  ZWE  2015.0           0.156465              0.609363
# 6466     Zimbabwe  ZWE  2016.0           0.157111              0.610234
# 6467     Zimbabwe  ZWE  2017.0           0.157963              0.611242
#
#       Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# ...

# %%
# Display basic info about the dataset
print("Dataset Info:")
print(df1.info())

# Display the first few rows of the dataset
print("\nFirst few rows of the dataset:")
print(df1.head())

# Summary statistics
print("\nSummary Statistics:")
print(df1.describe())

# Check for missing values
print("\nMissing Values:")
print(df1.isnull().sum())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Entity                     6468 non-null   object
#  1   Code                       5488 non-null   object
#  2   Year                       6468 non-null   float64
#  3   Schizophrenia (%)          6468 non-null   float64
#  4   Bipolar disorder (%)       6468 non-null   float64
#  5   Eating disorders (%)       6468 non-null   float64
#  6   Anxiety disorders (%)      6468 non-null   float64
#  7   Drug use disorders (%)     6468 non-null   float64
#  8   Depression (%)             6468 non-null   float64
#  9   Alcohol use disorders (%)  6468 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 505.4+ KB
# None
#
# First few rows of the dataset:
#         Entity Code    Year  Schizophrenia (%)  Bipolar disorder (%)  \
# ...

# %% [markdown]
# The dataset comprises 6468 entries, where each entry represents data for a specific entity, year, and disorder. The "Entity" column contains non-null object values, representing the name of the country, while the "Code" column has non-null object values representing the country's code.
#
# From the summary statistics, we observe variations in disorder prevalence across the years, with mean percentages ranging from approximately 0.21% for schizophrenia to about 3.99% for anxiety disorders.
#
# The code variable is the only one with missing values

# %%
from scipy import stats

# Define a threshold for outliers
threshold = 3

# Calculate z-scores for each numeric column
z_scores1 = stats.zscore(df1.select_dtypes(include=['number']))

# Find outliers
outliers1 = df1[(z_scores1 > threshold).any(axis=1)]

# Display outliers
print("\nOutliers:")
print(outliers1)
# Out:
# Outliers:
#              Entity Code    Year  Schizophrenia (%)  Bipolar disorder (%)  \
# 15      Afghanistan  AFG  2005.0           0.163706              0.703078
# 16      Afghanistan  AFG  2006.0           0.163977              0.703517
# 17      Afghanistan  AFG  2007.0           0.164302              0.703998
# 18      Afghanistan  AFG  2008.0           0.164639              0.704480
# 19      Afghanistan  AFG  2009.0           0.164932              0.704925
# ...             ...  ...     ...                ...                   ...
# 6099  United States  USA  2013.0           0.336404              0.652479
# 6100  United States  USA  2014.0           0.335860              0.652195
# 6101  United States  USA  2015.0           0.335243              0.651890
# 6102  United States  USA  2016.0           0.334578              0.651569
# 6103  United States  USA  2017.0           0.333890              0.651236
#
# ...

# %%
import matplotlib.pyplot as plt

# Filter out non-numeric columns
numeric_df1 = df1.select_dtypes(include='number')

# Remove the 'Year' column
numeric_df1 = numeric_df1.drop(columns=['Year'])

# Create a box plot
plt.figure(figsize=(10, 6))  # Set the figure size (optional)
plt.boxplot(numeric_df1.values, labels=numeric_df1.columns)  # Plot box plots for each numeric column
plt.title('Box Plot of Mental Disorders')  # Set the title of the plot
plt.xlabel('Disorder Type')  # Set the label for the x-axis
plt.ylabel('Percentage')  # Set the label for the y-axis
plt.grid(True)  # Enable grid (optional)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()  # Show the plot

# %% [markdown]
# ## Employment Rates Across Educational Levels: Active and Employed Percentages by Country, Code, and Year
#
# The dataset comprises information on employment rates across different educational levels, including active and employed percentages for all levels, below upper secondary, tertiary, and upper secondary & post-secondary non-tertiary, categorized by entity(country), code, and year.

# %%
df2
# Out:
#              Entity Code    Year  All levels (active) (%)  \
# 0           Austria  AUT  2014.0                      6.5
# 1           Belgium  BEL  2014.0                      5.0
# 2    Czech Republic  CZE  2014.0                      3.0
# 3           Denmark  DNK  2014.0                      6.7
# 4           Estonia  EST  2014.0                      3.8
# 5           Finland  FIN  2014.0                      8.5
# 6            France  FRA  2014.0                      5.2
# 7           Germany  DEU  2014.0                     10.3
# 8            Greece  GRC  2014.0                      2.8
# 9           Hungary  HUN  2014.0                      2.8
# 10          Iceland  ISL  2014.0                     10.7
# 11          Ireland  IRL  2014.0                     11.2
# 12            Italy  ITA  2014.0                      2.9
# 13           Latvia  LVA  2014.0                      7.0
# 14        Lithuania  LTU  2014.0                      2.1
# ...

# %% [markdown]
# ## Age-Stratified Depression Prevalence Dataset: Understanding Depression Across the Lifespan
#
# The dataset provides prevalence rates of depression across different age groups, spanning from adolescence (10-14 years old) to older adulthood (70+ years old), as well as age-standardized rates, offering insights into the varying impacts of depression across the lifespan.

# %%
df3
# Out:
#            Entity Code    Year  20-24 years old (%)  10-14 years old (%)  \
# 0     Afghanistan  AFG  1990.0             4.417802             1.594676
# 1     Afghanistan  AFG  1991.0             4.433524             1.588356
# 2     Afghanistan  AFG  1992.0             4.453689             1.577980
# 3     Afghanistan  AFG  1993.0             4.464517             1.577201
# 4     Afghanistan  AFG  1994.0             4.462960             1.570846
# ...           ...  ...     ...                  ...                  ...
# 6463     Zimbabwe  ZWE  2013.0             2.849725             1.057130
# 6464     Zimbabwe  ZWE  2014.0             2.856874             1.059057
# 6465     Zimbabwe  ZWE  2015.0             2.868684             1.062000
# 6466     Zimbabwe  ZWE  2016.0             2.893170             1.068818
# 6467     Zimbabwe  ZWE  2017.0             2.910070             1.073118
#
#       All ages (%)  70+ years old (%)  30-34 years old (%)  \
# ...

# %% [markdown]
# ## Gender-Specific Depression Prevalence Rates by Entity and Year: A Population-Based Analysis
#
# The dataset presents data on the prevalence of depression among both males and females, categorized by entity and year. It includes prevalence rates for both genders as well as population statistics.

# %%
df4
# Out:
#             Entity Code    Year  Prevalence in males (%)  \
# 0      Afghanistan  AFG  1800.0                      NaN
# 1      Afghanistan  AFG  1801.0                      NaN
# 2      Afghanistan  AFG  1802.0                      NaN
# 3      Afghanistan  AFG  1803.0                      NaN
# 4      Afghanistan  AFG  1804.0                      NaN
# ...            ...  ...     ...                      ...
# 47802     Zimbabwe  ZWE  2015.0                 2.789152
# 47803     Zimbabwe  ZWE  2016.0                 2.799308
# 47804     Zimbabwe  ZWE  2017.0                 2.812022
# 47805     Zimbabwe  ZWE  2018.0                      NaN
# 47806     Zimbabwe  ZWE  2019.0                      NaN
#
#        Prevalence in females (%)  Population
# 0                            NaN   3280000.0
# 1                            NaN   3280000.0
# 2                            NaN   3280000.0
# 3                            NaN   3280000.0
# 4                            NaN   3280000.0
# ...

# %% [markdown]
# ## Exploring the Interplay of Suicide Rates, Depressive Disorder Prevalence, and Population Dynamics Over Time and Across Entities
#
# This dataset compares suicide rates, prevalence of depressive disorder, and population figures across different years and entities, providing insights into the relationship between mental health indicators and demographic factors.

# %%
df5
# Out:
#             Entity Code    Year  \
# 0      Afghanistan  AFG  1800.0
# 1      Afghanistan  AFG  1801.0
# 2      Afghanistan  AFG  1802.0
# 3      Afghanistan  AFG  1803.0
# 4      Afghanistan  AFG  1804.0
# ...            ...  ...     ...
# 47802     Zimbabwe  ZWE  2015.0
# 47803     Zimbabwe  ZWE  2016.0
# 47804     Zimbabwe  ZWE  2017.0
# 47805     Zimbabwe  ZWE  2018.0
# 47806     Zimbabwe  ZWE  2019.0
#
#        Suicide rate (deaths per 100,000 individuals)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 47802                                      27.197061
# 47803                                      26.839591
# 47804                                      26.391769
# ...

# %% [markdown]
# ## Exploring Suicide and Depression Rates Across Time and Population
#
# The dataset provides information on suicide rates (deaths per 100,000 individuals) and depressive disorder rates (number suffering per 100,000) across different years, alongside population data.

# %%
df6
# Out:
#            Entity Code    Year  \
# 0     Afghanistan  AFG  1990.0
# 1     Afghanistan  AFG  1991.0
# 2     Afghanistan  AFG  1992.0
# 3     Afghanistan  AFG  1993.0
# 4     Afghanistan  AFG  1994.0
# ...           ...  ...     ...
# 6463     Zimbabwe  ZWE  2013.0
# 6464     Zimbabwe  ZWE  2014.0
# 6465     Zimbabwe  ZWE  2015.0
# 6466     Zimbabwe  ZWE  2016.0
# 6467     Zimbabwe  ZWE  2017.0
#
#       Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Number) (people suffering from depression)
# 0                                         318435.813670
# 1                                         329044.773956
# 2                                         382544.572895
# 3                                         440381.507393
# 4                                         456916.645489
# ...                                                 ...
# 6463                                      303564.603590
# 6464                                      311665.769283
# ...
